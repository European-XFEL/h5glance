# %% [markdown]
# ## H5Glance demo

# %%
import h5py, os

# %%
# Create some example HDF5 data to show
os.unlink("example.h5")
f = h5py.File("example.h5")
f.create_dataset("/group1/subgroup1/dataset1", (200,), dtype='u8')
f.create_dataset("/group1/subgroup1/dataset2", (2, 128, 500), dtype='f4')
f.create_dataset("/group1/subgroup2/dataset1", (12,), dtype='i2')

# Basic h5py repr
f
# Out:
# <HDF5 file "example.h5" (mode r+)>

# %% [markdown]
# ### Use H5Glance explicitly

# %%
from h5glance import H5Glance
H5Glance(f)
# Out:
# <div><style>/* Based on https://css-tricks.com/snippets/css/nested-expandable-folders/
#    Reused with permission from https://css-tricks.com/license/
# */
#
# .h5glance-css-treeview ul,
# .h5glance-css-treeview li
# {
# 	padding: 0;
# 	margin: 0;
#     margin-left: 12px;
# 	list-style: none;
# }
#
# /* Override padding from Jupyter CSS */
# .rendered_html .h5glance-css-treeview ul {
#     padding: 0;
# }
#
# .h5glance-css-treeview input
# {
# 	position: absolute;
# 	opacity: 0;
# }
#
# .h5glance-css-treeview
# {
#     font-family: sans-serif;
# 	-moz-user-select: none;
# 	-webkit-user-select: none;
# 	user-select: none;
# }
#
# .h5glance-css-treeview code {
#     font-size: 12pt;
#     font-family: "courier", monospace;
# }
#
# .h5glance-css-treeview a
# {
# 	color: #00f;
# 	text-decoration: none;
# }
#
# .h5glance-css-treeview a:hover
# {
# 	text-decoration: underline;
# }
#
# .h5glance-css-treeview input + label + ul
# {
# 	display: none;
# }
#
# .h5glance-css-treeview input:disabled + label
# {
# 	cursor: default;
# 	opacity: .6;
# }
#
# .h5glance-css-treeview input:checked:not(:disabled) + label + ul
# {
# 	display: block;
# }
#
# .h5glance-css-treeview label,
# .h5glance-css-treeview a,
# .h5glance-css-treeview label::before
# {
# 	display: inline-block;
# 	height: 16px;
# 	line-height: 16px;,
# 	vertical-align: middle;
# }
#
# .h5glance-css-treeview label
# {
# 	background-position: 18px 0;
#     margin-left: -1.5em;
# }
#
# .h5glance-css-treeview label::before
# {
# 	content: "+";
# 	width: 1.5em;
# 	vertical-align: middle;
# 	background-position: 0 -32px;
# }
#
# .h5glance-css-treeview input:checked + label::before
# {
#     content: "–";
# 	background-position: 0 -16px;
# }
#
# /* webkit adjacent element selector bugfix */
# @media screen and (-webkit-min-device-pixel-ratio:0)
# {
# 	.h5glance-css-treeview
# 	{
# 		-webkit-animation: webkit-adjacent-element-selector-bugfix infinite 1s;
# 	}
#
# 	@-webkit-keyframes webkit-adjacent-element-selector-bugfix
# 	{
# 		from
# 		{
# 			padding: 0;
# 		}
# 		to
# 		{
# 			padding: 0;
# 		}
# 	}
# }
#
# .h5glance-css-treeview li.h5glance-dataset {
#     margin-bottom: 3px;
# }
#
# .h5glance-dataset-name {
#     font-weight: bold;
# }
# </style><div class="h5glance-css-treeview"><ul><li><input checked="checked" id="item-0" type="checkbox"/><label for="item-0">example.h5</label><ul><li><input id="item-1" type="checkbox"/><label for="item-1">group1</label><ul><li><input id="item-2" type="checkbox"/><label for="item-2">subgroup1</label><ul><li class="h5glance-dataset"><span class="h5glance-dataset-name">dataset1</span>: 200 entries, dtype: <abbr title="64-bit unsigned integer"><code>&lt;u8</code></abbr></li><li class="h5glance-dataset"><span class="h5glance-dataset-name">dataset2</span>: 2 × 128 × 500 entries, dtype: <abbr title="32-bit floating point"><code>&lt;f4</code></abbr></li></ul></li><li><input id="item-3" type="checkbox"/><label for="item-3">subgroup2</label><ul><li class="h5glance-dataset"><span class="h5glance-dataset-name">dataset1</span>: 12 entries, dtype: <abbr title="16-bit signed integer"><code>&lt;i2</code></abbr></li></ul></li></ul></li></ul></li></ul></div></div>

# %%
H5Glance(f['group1/subgroup1'])
# Out:
# <div><style>/* Based on https://css-tricks.com/snippets/css/nested-expandable-folders/
#    Reused with permission from https://css-tricks.com/license/
# */
#
# .h5glance-css-treeview ul,
# .h5glance-css-treeview li
# {
# 	padding: 0;
# 	margin: 0;
#     margin-left: 12px;
# 	list-style: none;
# }
#
# /* Override padding from Jupyter CSS */
# .rendered_html .h5glance-css-treeview ul {
#     padding: 0;
# }
#
# .h5glance-css-treeview input
# {
# 	position: absolute;
# 	opacity: 0;
# }
#
# .h5glance-css-treeview
# {
#     font-family: sans-serif;
# 	-moz-user-select: none;
# 	-webkit-user-select: none;
# 	user-select: none;
# }
#
# .h5glance-css-treeview code {
#     font-size: 12pt;
#     font-family: "courier", monospace;
# }
#
# .h5glance-css-treeview a
# {
# 	color: #00f;
# 	text-decoration: none;
# }
#
# .h5glance-css-treeview a:hover
# {
# 	text-decoration: underline;
# }
#
# .h5glance-css-treeview input + label + ul
# {
# 	display: none;
# }
#
# .h5glance-css-treeview input:disabled + label
# {
# 	cursor: default;
# 	opacity: .6;
# }
#
# .h5glance-css-treeview input:checked:not(:disabled) + label + ul
# {
# 	display: block;
# }
#
# .h5glance-css-treeview label,
# .h5glance-css-treeview a,
# .h5glance-css-treeview label::before
# {
# 	display: inline-block;
# 	height: 16px;
# 	line-height: 16px;,
# 	vertical-align: middle;
# }
#
# .h5glance-css-treeview label
# {
# 	background-position: 18px 0;
#     margin-left: -1.5em;
# }
#
# .h5glance-css-treeview label::before
# {
# 	content: "+";
# 	width: 1.5em;
# 	vertical-align: middle;
# 	background-position: 0 -32px;
# }
#
# .h5glance-css-treeview input:checked + label::before
# {
#     content: "–";
# 	background-position: 0 -16px;
# }
#
# /* webkit adjacent element selector bugfix */
# @media screen and (-webkit-min-device-pixel-ratio:0)
# {
# 	.h5glance-css-treeview
# 	{
# 		-webkit-animation: webkit-adjacent-element-selector-bugfix infinite 1s;
# 	}
#
# 	@-webkit-keyframes webkit-adjacent-element-selector-bugfix
# 	{
# 		from
# 		{
# 			padding: 0;
# 		}
# 		to
# 		{
# 			padding: 0;
# 		}
# 	}
# }
#
# .h5glance-css-treeview li.h5glance-dataset {
#     margin-bottom: 3px;
# }
#
# .h5glance-dataset-name {
#     font-weight: bold;
# }
# </style><div class="h5glance-css-treeview"><ul><li><input checked="checked" id="item-4" type="checkbox"/><label for="item-4">/group1/subgroup1</label><ul><li class="h5glance-dataset"><span class="h5glance-dataset-name">dataset1</span>: 200 entries, dtype: <abbr title="64-bit unsigned integer"><code>&lt;u8</code></abbr></li><li class="h5glance-dataset"><span class="h5glance-dataset-name">dataset2</span>: 2 × 128 × 500 entries, dtype: <abbr title="32-bit floating point"><code>&lt;f4</code></abbr></li></ul></li></ul></div></div>

# %% [markdown]
# ### View all h5py objects
#
# Install a display hook for IPython so all `h5py` files & groups are viewed this way.

# %%
import h5glance
h5glance.install_ipython_h5py_display()

# %%
f
# Out:
# <HDF5 file "example.h5" (mode r+)>

# %%
f['group1']
# Out:
# <HDF5 group "/group1" (2 members)>
